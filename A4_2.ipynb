# %%
from urllib.request import urlopen
from urllib.parse import urljoin
from html.parser import HTMLParser
import re
import operator

# %%
class Collector(HTMLParser):
    'collects hyperlink URLs into a list'

    def __init__(self, url):
        'initializes parser, the url, and a list'
        HTMLParser.__init__(self)
        self.url = url
        self.links = []
        self.data = []

    def handle_starttag(self, tag, attrs):
        'collects hyperlink URLs in their absolute format'
        if tag == 'a':
            for attr in attrs:
                if attr[0] == 'href':
                    # construct absolute URL
                    absolute = urljoin(self.url, attr[1])
                    # collect HTTP URLs from cdm.depaul.edu pages and limit responses to active server pages
                    if absolute[:26] == 'https://www.cdm.depaul.edu' and absolute[-4:] == 'aspx':
                        self.links.append(absolute)
                        
    
    def getLinks(self):
        'returns hyperlinks URLs in their absolute format'
        return self.links

# %%
def getContent(url):
    '''takes in url and returns the content as a string'''
    response = urlopen(url)
    htmlSource = response.read()    
    response.close()
    content = htmlSource.decode().lower()
    return content

# %%
def getLinks(url):
    '''gets links from content'''
    linkContent = getContent(url)
    collector = Collector(url)
    collector.feed(linkContent)
    return collector.getLinks()

# %%
def wordDict(content):
    '''goes through content and pulls out all text then modifies the word dictionary'''
    global wDict
    pList = []
    paragraphs = re.findall(r'<p>(.*?)</p>',str(content))
    for p in paragraphs:
        pList += p.split(' ')
    headers = re.findall(r'<h2>(.*?)</h2>',str(content))
    for h in headers:
        pList += h.split(' ')

    for x in pList:
        if x in wDict:
            wDict[x] += 1
        elif x not in wDict:
            wDict[x] = 1

# %%
#declaring variables
wDict = {}
linksGathered, linksCalled, linksErr = [], [], []

#gets content from first link then gathers all links from that page
baseurl = 'https://www.cdm.depaul.edu'
links = getLinks(baseurl)
linksCalled.append(baseurl)
wordDict(getContent(baseurl))

for link in links:
    if link not in linksGathered:
        linksGathered.append(link)

#recursively runs the functions for all links gathered
#handles for errors with web page
for url in linksGathered:
    if url not in linksCalled:
        try:
            links = getLinks(url)
            linksCalled.append(url)
            wordDict(getContent(url))
        except:
            linksErr.append(url)
        for link in links:
            if link not in linksGathered:
                linksGathered.append(link)

top15 = sorted(wDict.items(), key=operator.itemgetter(1), reverse=True)[:25]
print(top15)
# Out:
# https://www.cdm.depaul.edu/prospective%20students/pages/mastersdegreestudents.aspx
# https://www.cdm.depaul.edu/academics/pages/mfa-in-creative-producing.aspx
# https://www.cdm.depaul.edu/academics/pages/windrider-forum-at-sundance.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ms-in-cybersecurity-computer-security.aspx
# https://www.cdm.depaul.edu/current%20students/pages/labsandresources/lab658-9.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ma-in-animation-animator.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-mfa-in-film-and-television.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ms-is-it-enterprise-management.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ms-in-predictive-analytics-computational.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ms-in-predictive-analytics-health-care.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ms-in-predictive-analytics-hospitality.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-ms-in-predictive-analytics-marketing.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-mfa-in-screenwriting.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bs-game-development-gameplay-programming.aspx
# https://www.cdm.depaul.edu/academics/pages/2017/requirements-jdms-joint-degree.aspx
# https://www.cdm.depaul.edu/academics/pages/2017/requirements-ms-e-commerce-technology.aspx
# https://www.cdm.depaul.edu/academics/pages/2014/requirements-ms-se-gaming-and-entertainment.aspx
# https://www.cdm.depaul.edu/academics/pages/2018/requirements-bfa-in-animation-motion-graphics.aspx
# https://www.cdm.depaul.edu/academics/pages/2018/requirements-bfa-in-animation-3d-animation.aspx
# https://www.cdm.depaul.edu/academics/pages/2018/requirements-bfa-in-film-and-television-comedy.aspx
# https://www.cdm.depaul.edu/academics/pages/2018/requirements-bfa-in-film-and-television-showrunner.aspx
# https://www.cdm.depaul.edu/academics/pages/2018/requirements-bs-in-user-experience-design-design.aspx
# https://www.cdm.depaul.edu/academics/pages/2018/requirements-bs-in-user-experience-design-development.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-animation-storyboarding-and-character-design.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bs-in-cyber-physical-systems-engineering.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bs-in-cybersecurity.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bs-in-data-science.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-ba-in-film-and-television.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-cinematography.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-creative-producing.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-directing.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-documentary.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-editing.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-production-design.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-sound-design.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-visual-effects.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bfa-in-film-and-television-screenwriting.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bs-in-game-design.aspx
# https://www.cdm.depaul.edu/academics/pages/2016/requirements-bs-in-game-programming.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-bs-in-interactive-media-design.aspx
# https://www.cdm.depaul.edu/academics/pages/current/requirements-bs-in-interactive-media-development.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bs-in-animation.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bainanimation.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsincomputergamesdevelopement.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsincomputerscience.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bacomputing.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsindigitalcinema.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/baindigitalcinema.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bfaingraphicdesign.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsiniase.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bs_informationsystems_analyst.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsininformationtechnology.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bs-in-interactive-media.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsinmathcomputerscience.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/bsinnetworktechnology.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ma-in-animation.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ma-in-animation-technical-artist.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/ms_appliedtechnology.aspx
# https://www.cdm.depaul.edu/academics/pages/2013fall/ms-in-predictive-analytics.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ma-in-animation-animator.aspx
# https://www.cdm.depaul.edu/academics/pages/2017/requirements-mfa-in-film-and-television.aspx
# https://www.cdm.depaul.edu/academics/pages/2017/requirements-ms-in-film-and-television-cinematography.aspx
# https://www.cdm.depaul.edu/academics/pages/2017/requirements-ms-in-film-and-television-post-production.aspx
# https://www.cdm.depaul.edu/academics/pages/2017/requirements-ms-in-film-and-television-sound.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/msinbusinessinformationtechnology.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/msdigitalcinema.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/msinitprojectmanagement.aspx
# https://www.cdm.depaul.edu/academics/pages/msinpredictiveanalytics.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/msincomputerinformationandnetworksecurity.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_cins_informationsystems.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_cins_networksecurity.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_cins_compliance.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_cins_computersecurity.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/msininformationsystems.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_standard.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_projectmanagement.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_enterprisesystemsintegration.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_informationtechnologymanagement.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_businesswebanalysisanddevelopment.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_managingebusiness.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_businessintelligence.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_informationsecurityandcompliance.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_databaseadministration.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_is_businessanalysissystemsanalysis.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/msinsoftwareengineering.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_se_softwaredevelopment.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_se_softwarearchitecture.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_se_projectmanagement.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms_se_gamingandentertainment.aspx
# https://www.cdm.depaul.edu/academics/old/old/2013fall-%20editing/ms-se-entrepreneurship.aspx

# %%
'''
Below is the output of my script. I limited the links to active server pages (.aspx)
It checks 831 links and takes ~7 minutes to run.

[('the', 5546),
 ('and', 3489),
 ('of', 3135),
 ('to', 2894),
 ('in', 2720),
 ('a', 2575),
 ('students', 2187),
 ('for', 1593),
 ('is', 1292),
 ('or', 1277),
 ('with', 1098),
 ('be', 1002),
 ('will', 993),
 ('are', 982),
 ('course', 974),]
 '''
# Out:
# 748
# 90
# 831
# {'the': 5546, 'next': 18, 'generation': 16, 'of': 3135, 'visual': 45, 'storytellers,': 3, 'taught': 23, 'by': 347, 'professional': 108, 'filmmakers,': 3, 'utilizing': 5, 'latest': 15, 'technology': 90, 'and': 3489, 'a': 2575, '32,000': 4, 'sq.': 3, 'ft.': 3, 'production': 72, 'facility': 10, 'innovative': 27, 'nationally': 4, 'recognized': 4, 'programs,': 11, 'inspiring': 4, 'teachers,': 5, 'strong': 26, 'connections': 8, 'with': 1098, 'industry,': 16, 'drawing': 6, 'on': 635, 'cutting': 8, 'edge': 8, 'research': 224, 'established': 25, 'emerging': 20, 'design': 153, 'disciplines': 10, 'focusing': 6, 'collaboration,': 4, 'critical': 30, 'thinking,': 7, 'research,': 11, 'play,': 6, 'socio-cultural': 3, 'problem': 5, 'solving': 8, 'community': 23, 'endless': 3, 'possibilities': 3, 'ipd': 114, 'offers': 46, '<a': 1665, 'href="/ipd/programs/pages/programsofstudy.aspx">intensive': 3, 'certificate': 78, 'programs</a>': 4, 'designed': 91, 'for': 1593, 'it': 407, 'professionals': 41, 'who': 330, 'wish': 68, 'to': 2894, 'learn': 110, 'new': 77, 'technologies': 34, 'upgrade': 7, 'their': 453, 'skills': 110, 'in': 2720, 'short': 34, 'amount': 17, 'time.': 13, 'href="/pages/privacy.aspx"': 1448, 'style="font-size:': 1448, '11px;': 1448, 'float:': 1448, 'left;': 742, 'margin:': 1448, '0;': 1448, 'text-shadow:': 742, 'none;': 742, 'clear:': 742, 'both;"': 742, 'data-area="footer">privacy': 742, 'statement</a>': 1448, '-36px': 706, '10px': 706, '0': 706, 'right;': 706, 'color:': 706, '#ddd;': 706, 'clear:both;">privacy': 706, 'site': 752, 'menu': 743, 'quicklinks': 742, 'cinematic': 43, 'arts': 65, 'computing': 98, '3': 6, 'schools': 11, '<p>for': 1, 'more': 135, 'information:': 1, 'href="http://colloquium.cdm.depaul.edu/': 1, '">http://colloquium.cdm.depaul.edu/': 1, '</a>': 2, 'amidst': 1, 'political': 4, 'scandal': 1, 'fiscal': 1, 'crisis,': 1, '26-year-old': 1, 'activist': 2, 'will': 993, 'guzzardi': 2, 'believes': 4, 'that': 671, 'he': 44, 'can': 318, 'mobilize': 1, 'movement': 2, 'upend': 1, 'illinois&rsquo;': 1, 'dysfunctional': 1, 'system.': 28, 'but': 89, 'chose': 2, 'run': 6, 'against': 1, 'daughter': 1, 'one': 366, 'best': 12, 'connected': 3, 'politicians': 1, 'chicago': 26, '&mdash;': 3, 'establishment': 1, 'is': 1292, 'not': 257, 'going': 2, 'let': 2, 'her': 28, 'go': 6, 'down': 1, 'without': 14, 'fight.': 1, '39th': 1, 'follows': 24, 'as': 622, 'grows': 1, 'up,': 1, 'from': 372, 'politician,': 1, 'learns': 1, 'what': 14, 'really': 1, 'takes': 32, 'an': 473, 'outsider': 1, 'win': 1, 'govern': 1, 'within': 60, 'machine.': 1, 'trailer&nbsp;<a': 1, 'href="https://youtu.be/ob6e5cwmatg">https://youtu.be/ob6e5cwmatg</a>': 1, 'on-stage': 2, 'conversation': 1, 'immediately': 5, 'following': 121, 'film': 84, 'with:': 1, '<p>this': 4, 'tour': 12, 'prospective': 8, 'students': 2187, 'guests': 5, 'are': 982, 'interested': 52, 'specifically': 6, 'touring': 3, 'depaul': 514, 'cdm&rsquo;s': 4, 'space': 17, 'at': 612, 'cinespace': 19, 'studios.': 11, '&nbsp;the': 2, 'meet': 61, 'cdm': 384, 'center,': 42, 'there,': 4, 'participants': 25, 'be': 1002, 'shuttled': 6, '&nbsp;an': 2, 'hour-long': 3, 'walking': 4, 'through': 128, 'three': 74, 'stages': 6, 'occur': 6, 'before': 68, 'back': 6, 'center.': 6, '': 816, '<p>learn': 1, 'about': 97, 'getting': 4, 'phd': 59, 'pursuing': 11, 'opportunities': 68, 'cdm.': 24, '<p>lecture': 1, 'presented': 2, 'shayna': 3, 'connelly': 2, 'women': 7, 'have': 403, 'played': 3, 'integral': 10, 'role': 9, 'cinema': 25, 'beginning,': 1, 'achievements': 1, 'always': 9, 'been': 47, 'recognized.': 1, 'it&rsquo;s': 1, 'time': 61, 'set': 16, 'record': 13, 'straight': 2, 'credit': 275, 'pioneering': 2, 'female': 7, 'filmmakers': 18, 'changed': 1, 'history.': 1, 'filmmaker': 4, 'professor': 21, 'invites': 12, 'you': 196, 'pushed': 1, 'boundaries': 1, 'form,': 4, 'starting': 5, 'such': 77, 'alice': 1, 'guy-blach&eacute;,': 1, 'lois': 1, 'weber': 1, 'germaine': 1, 'dulac.': 1, 'celebrate': 1, 'women&rsquo;s': 1, 'history': 8, 'm ...
